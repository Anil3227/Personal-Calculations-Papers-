# %% [markdown]
# w0 -wa Plane

# %%
from getdist import MCSamples, plots
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.lines as mlines


# ---------- load chains ----------
data1 = np.loadtxt('/Users/anilkandel/Documents/SimpleMC Dovekie/simplemc/chains/wCDM_phy_PLK18+DESIDR2+Desdovekie_mcmc_1.txt')
data2 = np.loadtxt('/Users/anilkandel/Documents/SimpleMC Dovekie/simplemc/chains/wCDM_phy_PLK18+DESIDR2+DESY5_mcmc_1.txt')

weights1 = np.ones(data1.shape[0])
weights2 = np.ones(data2.shape[0])

# first 6 columns; param3 = w0
params1 = data1[:, :6]
params2 = data2[:, :6]

param_names  = ['param1','param2','Om','Obh2','h','param3']
param_labels = ['Param1','Param2',r'\Omega_m',r'\Omega_b h^2',r'h',r'\omega']

samples1 = MCSamples(samples=params1, weights=weights1, names=param_names, labels=param_labels)
samples2 = MCSamples(samples=params2, weights=weights2, names=param_names, labels=param_labels)

# ------------------- 2D Plot for Om and w0 -------------------
g2d = plots.get_single_plotter(width_inch=6)
g2d.settings.figure_legend_frame = True
g2d.settings.alpha_filled_add = 0.7
g2d.settings.axes_labelsize = 10
g2d.settings.legend_fontsize = 10

# Create a 2D plot for Om and w0 for both chains
g2d.plot_2d(
    [samples1, samples2],
    param_pair=['param3', 'Om'],  # w0 and Om
    filled=[False, True],
    colors=['darkblue', 'magenta'],   # dark blue for DESDovekie, magenta for DESY5
    contour_ls=['--', '-'],           # dashed for dark blue, solid for magenta
)

# ------------------- Force dashed line for first contour -------------------
ax = g2d.subplots[0,0] # type: ignore

# Ensure first contour (blue) is dashed
for line in ax.collections[:len(ax.collections)//2]:
    line.set_linestyle('--')

# ------------------- Add legend with dashed line -------------------
# Create custom legend handles
handle1 = mlines.Line2D([], [], color='darkblue', linestyle='--', label=r'CMB+DESI DR2+DES-Dovekie')
handle2 = mlines.Line2D([], [], color='magenta', linestyle='-', label=r'CMB+DESI DR2+DES-SN5Y')

# Add legend to the axis
ax.legend(handles=[handle1, handle2], fontsize=8, loc='upper right', frameon=True)

# ------------------- Add reference lines and ΛCDM point -------------------
ax = g2d.subplots[0, 0]  # type: ignore # Get the axis from GetDist plotter

# Vertical dashed lines
ax.axvline(x=-1, color='gray', linestyle='--', linewidth=1.2)

# Export the 2D plot
g2d.export("pdfs/wCDM_anil2.pdf")
# Out:
# Removed no burn in
# Removed no burn in

# %%
from getdist import MCSamples, plots
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.lines as mlines


# ---------- load chains ----------
data1 = np.loadtxt('/Users/anilkandel/Documents/SimpleMC Dovekie/simplemc/chains/CPL_phy_PLK18+DESIDR2+Desdovekie_mcmc_1.txt')
data2 = np.loadtxt('/Users/anilkandel/Documents/SimpleMC Dovekie/simplemc/chains/CPL_phy_PLK18+DESIDR2+DESY5_mcmc_1.txt')

weights1 = np.ones(data1.shape[0])
weights2 = np.ones(data2.shape[0])

# first 7 columns; param3 = w0, param5 = wa
params1 = data1[:, :7]
params2 = data2[:, :7]

param_names  = ['param1','param2','Om','Obh2','h','param3','param5']
param_labels = ['Param1','Param2',r'\Omega_m',r'\Omega_b h^2',r'h',r'\omega_0',r'\omega_a']

samples1 = MCSamples(samples=params1, weights=weights1, names=param_names, labels=param_labels)
samples2 = MCSamples(samples=params2, weights=weights2, names=param_names, labels=param_labels)

# ------------------- 2D Plot for w0 and wa -------------------
g2d = plots.get_single_plotter(width_inch=6)
g2d.settings.figure_legend_frame = True
g2d.settings.alpha_filled_add = 0.7
g2d.settings.axes_labelsize = 10
g2d.settings.legend_fontsize = 10

# Create a 2D plot for w0 and wa for both chains
g2d.plot_2d(
    [samples1, samples2],
    param_pair=['param3', 'param5'],  # w0 and wa
    filled=[False, True],
    colors=['darkblue', 'magenta'],   # dark blue for DESDovekie, magenta for DESY5
    contour_ls=['--', '-'],           # dashed for dark blue, solid for magenta
)

# ------------------- Force dashed line for first contour -------------------
ax = g2d.subplots[0,0] # type: ignore

# Ensure first contour (blue) is dashed
for line in ax.collections[:len(ax.collections)//2]:
    line.set_linestyle('--')

# ------------------- Add legend with dashed line -------------------
# Create custom legend handles
handle1 = mlines.Line2D([], [], color='darkblue', linestyle='--', label=r'CMB+DESI DR2+DES-Dovekie')
handle2 = mlines.Line2D([], [], color='magenta', linestyle='-', label=r'CMB+DESI DR2+DES-SN5Y')

# Add legend to the axis
ax.legend(handles=[handle1, handle2], fontsize=8, loc='upper right', frameon=True)

# ------------------- Add reference lines and ΛCDM point -------------------
ax = g2d.subplots[0, 0]  # type: ignore # Get the axis from GetDist plotter

# Vertical and horizontal dashed lines
ax.axvline(x=-1, color='gray', linestyle='--', linewidth=1.2)
ax.axhline(y=0, color='gray', linestyle='--', linewidth=1.2)

# ΛCDM marker and annotation
ax.plot([-1], [0], marker='*', ms=12, color='k', zorder=5)

ax.annotate(
    r'$\Lambda$CDM',
    xy=(-1, 0),
    xytext=(-0.93, 0.22),
    fontsize=11,
    fontweight='bold',
    color='black',
    arrowprops=dict(arrowstyle='->', lw=1.2, color='black'),
    zorder=5
)

# Export the 2D plot
g2d.export("pdfs/CPL_anil2.pdf")
# Out:
# Removed no burn in
# Removed no burn in

# %%
from getdist import MCSamples, plots
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.lines as mlines


# ---------- load chains ----------
data1 = np.loadtxt('/Users/anilkandel/Documents/SimpleMC Dovekie/simplemc/chains/BA_phy_PLK18+DESIDR2+Desdovekie_mcmc_1.txt')
data2 = np.loadtxt('/Users/anilkandel/Documents/SimpleMC Dovekie/simplemc/chains/BA_phy_PLK18+DESIDR2+DESY5_mcmc_1.txt')

weights1 = np.ones(data1.shape[0])
weights2 = np.ones(data2.shape[0])

# first 7 columns; param3 = w0, param5 = wa
params1 = data1[:, :7]
params2 = data2[:, :7]

param_names  = ['param1','param2','Om','Obh2','h','param3','param5']
param_labels = ['Param1','Param2',r'\Omega_m',r'\Omega_b h^2',r'h',r'\omega_0',r'\omega_a']

samples1 = MCSamples(samples=params1, weights=weights1, names=param_names, labels=param_labels)
samples2 = MCSamples(samples=params2, weights=weights2, names=param_names, labels=param_labels)

# ------------------- 2D Plot for w0 and wa -------------------
g2d = plots.get_single_plotter(width_inch=6)
g2d.settings.figure_legend_frame = True
g2d.settings.alpha_filled_add = 0.7
g2d.settings.axes_labelsize = 10
g2d.settings.legend_fontsize = 10

# Create a 2D plot for w0 and wa for both chains
g2d.plot_2d(
    [samples1, samples2],
    param_pair=['param3', 'param5'],  # w0 and wa
    filled=[False, True],
    colors=['darkblue', 'magenta'],   # dark blue for DESDovekie, magenta for DESY5
    contour_ls=['--', '-'],           # dashed for dark blue, solid for magenta
)

# ------------------- Force dashed line for first contour -------------------
ax = g2d.subplots[0,0] # type: ignore

# Ensure first contour (blue) is dashed
for line in ax.collections[:len(ax.collections)//2]:
    line.set_linestyle('--')

# ------------------- Add legend with dashed line -------------------
# Create custom legend handles
handle1 = mlines.Line2D([], [], color='darkblue', linestyle='--', label=r'CMB+DESI DR2+DES-Dovekie')
handle2 = mlines.Line2D([], [], color='magenta', linestyle='-', label=r'CMB+DESI DR2+DES-SN5Y')

# Add legend to the axis
ax.legend(handles=[handle1, handle2], fontsize=8, loc='upper right', frameon=True)

# ------------------- Add reference lines and ΛCDM point -------------------
ax = g2d.subplots[0, 0]  # type: ignore # Get the axis from GetDist plotter

# Vertical and horizontal dashed lines
ax.axvline(x=-1, color='gray', linestyle='--', linewidth=1.2)
ax.axhline(y=0, color='gray', linestyle='--', linewidth=1.2)

# ΛCDM marker and annotation
ax.plot([-1], [0], marker='*', ms=12, color='k', zorder=5)

ax.annotate(
    r'$\Lambda$CDM',
    xy=(-1, 0),
    xytext=(-0.93, 0.1),
    fontsize=11,
    fontweight='bold',
    color='black',
    arrowprops=dict(arrowstyle='->', lw=1.2, color='black'),
    zorder=5
)

# Export the 2D plot
g2d.export("pdfs/BA_anil2.pdf")
# Out:
# Removed no burn in
# Removed no burn in

# %%
from getdist import MCSamples, plots
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.lines as mlines


# ---------- load chains ----------
data1 = np.loadtxt('/Users/anilkandel/Documents/SimpleMC Dovekie/simplemc/chains/JBP_phy_PLK18+DESIDR2+Desdovekie_mcmc_1.txt')
data2 = np.loadtxt('/Users/anilkandel/Documents/SimpleMC Dovekie/simplemc/chains/JBP_phy_PLK18+DESIDR2+DESY5_mcmc_1.txt')

weights1 = np.ones(data1.shape[0])
weights2 = np.ones(data2.shape[0])

# first 7 columns; param3 = w0, param5 = wa
params1 = data1[:, :7]
params2 = data2[:, :7]

param_names  = ['param1','param2','Om','Obh2','h','param3','param5']
param_labels = ['Param1','Param2',r'\Omega_m',r'\Omega_b h^2',r'h',r'\omega_0',r'\omega_a']

samples1 = MCSamples(samples=params1, weights=weights1, names=param_names, labels=param_labels)
samples2 = MCSamples(samples=params2, weights=weights2, names=param_names, labels=param_labels)

# ------------------- 2D Plot for w0 and wa -------------------
g2d = plots.get_single_plotter(width_inch=6)
g2d.settings.figure_legend_frame = True
g2d.settings.alpha_filled_add = 0.7
g2d.settings.axes_labelsize = 10
g2d.settings.legend_fontsize = 10

# Create a 2D plot for w0 and wa for both chains
g2d.plot_2d(
    [samples1, samples2],
    param_pair=['param3', 'param5'],  # w0 and wa
    filled=[False, True],
    colors=['darkblue', 'magenta'],   # dark blue for DESDovekie, magenta for DESY5
    contour_ls=['--', '-'],           # dashed for dark blue, solid for magenta
)

# ------------------- Force dashed line for first contour -------------------
ax = g2d.subplots[0,0] # type: ignore

# Ensure first contour (blue) is dashed
for line in ax.collections[:len(ax.collections)//2]:
    line.set_linestyle('--')

# ------------------- Add legend with dashed line -------------------
# Create custom legend handles
handle1 = mlines.Line2D([], [], color='darkblue', linestyle='--', label=r'CMB+DESI DR2+DES-Dovekie')
handle2 = mlines.Line2D([], [], color='magenta', linestyle='-', label=r'CMB+DESI DR2+DES-SN5Y')

# Add legend to the axis
ax.legend(handles=[handle1, handle2], fontsize=8, loc='upper right', frameon=True)

# ------------------- Add reference lines and ΛCDM point -------------------
ax = g2d.subplots[0, 0]  # type: ignore # Get the axis from GetDist plotter

# Vertical and horizontal dashed lines
ax.axvline(x=-1, color='gray', linestyle='--', linewidth=1.2)
ax.axhline(y=0, color='gray', linestyle='--', linewidth=1.2)

# ΛCDM marker and annotation
ax.plot([-1], [0], marker='*', ms=12, color='k', zorder=5)

ax.annotate(
    r'$\Lambda$CDM',
    xy=(-1, 0),
    xytext=(-0.86, 0.5),
    fontsize=11,
    fontweight='bold',
    color='black',
    arrowprops=dict(arrowstyle='->', lw=1.2, color='black'),
    zorder=5
)

# Export the 2D plot
g2d.export("pdfs/JBP_anil2.pdf")
# Out:
# Removed no burn in
# Removed no burn in

# %%
from getdist import MCSamples, plots
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.lines as mlines


# ---------- load chains ----------
data1 = np.loadtxt('/Users/anilkandel/Documents/SimpleMC Dovekie/simplemc/chains/Logarithmic_phy_DESIDR2+PLK18+Desdovekie_mcmc_1.txt')
data2 = np.loadtxt('/Users/anilkandel/Documents/SimpleMC Dovekie/simplemc/chains/Logarithmic_phy_DESIDR2+PLK18+DESY5_mcmc_1.txt')

weights1 = np.ones(data1.shape[0])
weights2 = np.ones(data2.shape[0])

# first 7 columns; param3 = w0, param5 = wa
params1 = data1[:, :7]
params2 = data2[:, :7]

param_names  = ['param1','param2','Om','Obh2','h','param3','param5']
param_labels = ['Param1','Param2',r'\Omega_m',r'\Omega_b h^2',r'h',r'\omega_0',r'\omega_a']

samples1 = MCSamples(samples=params1, weights=weights1, names=param_names, labels=param_labels)
samples2 = MCSamples(samples=params2, weights=weights2, names=param_names, labels=param_labels)

# ------------------- 2D Plot for w0 and wa -------------------
g2d = plots.get_single_plotter(width_inch=6)
g2d.settings.figure_legend_frame = True
g2d.settings.alpha_filled_add = 0.7
g2d.settings.axes_labelsize = 10
g2d.settings.legend_fontsize = 10

# Create a 2D plot for w0 and wa for both chains
g2d.plot_2d(
    [samples1, samples2],
    param_pair=['param3', 'param5'],  # w0 and wa
    filled=[False, True],
    colors=['darkblue', 'magenta'],   # dark blue for DESDovekie, magenta for DESY5
    contour_ls=['--', '-'],           # dashed for dark blue, solid for magenta
)

# ------------------- Force dashed line for first contour -------------------
ax = g2d.subplots[0,0] # type: ignore

# Ensure first contour (blue) is dashed
for line in ax.collections[:len(ax.collections)//2]:
    line.set_linestyle('--')

# ------------------- Add legend with dashed line -------------------
# Create custom legend handles
handle1 = mlines.Line2D([], [], color='darkblue', linestyle='--', label=r'CMB+DESI DR2+DES-Dovekie')
handle2 = mlines.Line2D([], [], color='magenta', linestyle='-', label=r'CMB+DESI DR2+DES-SN5Y')

# Add legend to the axis
ax.legend(handles=[handle1, handle2], fontsize=8, loc='upper right', frameon=True)

# ------------------- Add reference lines and ΛCDM point -------------------
ax = g2d.subplots[0, 0]  # type: ignore # Get the axis from GetDist plotter

# Vertical and horizontal dashed lines
ax.axvline(x=-1, color='gray', linestyle='--', linewidth=1.2)
ax.axhline(y=0, color='gray', linestyle='--', linewidth=1.2)

# ΛCDM marker and annotation
ax.plot([-1], [0], marker='*', ms=12, color='k', zorder=5)

ax.annotate(
    r'$\Lambda$CDM',
    xy=(-1, 0),
    xytext=(-0.90, 0.15),
    fontsize=11,
    fontweight='bold',
    color='black',
    arrowprops=dict(arrowstyle='->', lw=1.2, color='black'),
    zorder=5
)

# Export the 2D plot
g2d.export("pdfs/Logarithmic_anil2.pdf")
# Out:
# Removed no burn in
# Removed no burn in

# %%
from getdist import MCSamples, plots
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.lines as mlines


# ---------- load chains ----------
data1 = np.loadtxt('/Users/anilkandel/Documents/SimpleMC Dovekie/simplemc/chains/GEDE_phy_PLK18+DESIDR2+Desdovekie_mcmc_1.txt')
data2 = np.loadtxt('/Users/anilkandel/Documents/SimpleMC Dovekie/simplemc/chains/GEDE_phy_PLK18+DESIDR2+DESY5_mcmc_1.txt')

weights1 = np.ones(data1.shape[0])
weights2 = np.ones(data2.shape[0])

# first 7 columns; param3 = w0, param5 = wa
params1 = data1[:, :6]
params2 = data2[:, :6]

param_names  = ['param1','param2','Om','Obh2','h','Delta']
param_labels = ['Param1','Param2',r'\Omega_m',r'\Omega_b h^2',r'h',r'\Delta']

samples1 = MCSamples(samples=params1, weights=weights1, names=param_names, labels=param_labels)
samples2 = MCSamples(samples=params2, weights=weights2, names=param_names, labels=param_labels)

# ------------------- 2D Plot for w0 and wa -------------------
g2d = plots.get_single_plotter(width_inch=6)
g2d.settings.figure_legend_frame = True
g2d.settings.alpha_filled_add = 0.7
g2d.settings.axes_labelsize = 10
g2d.settings.legend_fontsize = 10

# Create a 2D plot for Om and Delta for both chains
g2d.plot_2d(
    [samples1, samples2],
    param_pair=['Delta', 'Om'],  # Om and Delta
    filled=[False, True],
    colors=['darkblue', 'magenta'],   # dark blue for DESDovekie, magenta for DESY5
    contour_ls=['--', '-'],           # dashed for dark blue, solid for magenta
)

# ------------------- Force dashed line for first contour -------------------
ax = g2d.subplots[0,0] # type: ignore

# Ensure first contour (blue) is dashed
for line in ax.collections[:len(ax.collections)//2]:
    line.set_linestyle('--')

# ------------------- Add legend with dashed line -------------------
# Create custom legend handles
handle1 = mlines.Line2D([], [], color='darkblue', linestyle='--', label=r'CMB+DESI DR2+DES-Dovekie')
handle2 = mlines.Line2D([], [], color='magenta', linestyle='-', label=r'CMB+DESI DR2+DES-SN5Y')

# Add legend to the axis
ax.legend(handles=[handle1, handle2], fontsize=8, loc='upper right', frameon=True)

# ------------------- Add reference lines and ΛCDM point -------------------
ax = g2d.subplots[0, 0]  # type: ignore # Get the axis from GetDist plotter

# Vertical and horizontal dashed lines
ax.axvline(x=0, color='gray', linestyle='--', linewidth=1.2)
ax.text(
    0.02,                   # small shift to the right
    ax.get_ylim()[1]*0.95,
    r'$\Lambda$CDM',
    rotation=90,
    color='black',
    fontsize=9
)

# Export the 2D plot
g2d.export("pdfs/GEDE_anil2.pdf")
# Out:
# Removed no burn in
# Removed no burn in

# %% [markdown]
# Deviation

# %%
# ===============================================================
# Function for computing deviation from reference (fix formula)
# ===============================================================
def sigma_deviation_from_ref(value, err_minus, err_plus, ref=-1.0):
    delta = abs(value - ref)
    sigma_avg = (err_minus + err_plus) / 2.0
    n_sigma_avg = delta / sigma_avg
    n_sigma_minus = delta / err_minus
    n_sigma_plus = delta / err_plus
    return {
        "average_error": n_sigma_avg,
        "minus_error": n_sigma_minus,
        "plus_error": n_sigma_plus
    }

# ==============================================================================
# w0 values ± errors extracted from your table , PLUS MINUS error put positive
# ==============================================================================
datasets = [
    # ----------- wCDm -----------
     #  error bar magnitude is always positive.
    ("CMB + DESI DR2 + Des-Dovekie",    -0.964, 0.025, 0.025),  # you can change these values and test with papers
    ("CMB + DESI DR2 + DES-SN5Y",       -0.945, 0.023, 0.025),


    # ----------- CPL -----------
     #  error bar magnitude is always positive.
    ("CMB + DESI DR2 + Des-Dovekie",    -0.865, 0.052, 0.052),  # you can change these values and test with papers
    ("CMB + DESI DR2 + DES-SN5Y",       -0.798, 0.052, 0.052),


    # ----------- BA -----------
     #  error bar magnitude is always positive.
    ("CMB + DESI DR2 + Des-Dovekie",    -0.876, 0.054, 0.054),  # you can change these values and test with papers
    ("CMB + DESI DR2 + DES-SN5Y",       -0.841, 0.044, 0.049),


    # ----------- JBP -----------
     #  error bar magnitude is always positive.
    ("CMB + DESI DR2 + Des-Dovekie",    -0.785, 0.085, 0.085),  # you can change these values and test with papers
    ("CMB + DESI DR2 + DES-SN5Y",       -0.751, 0.075, 0.075),


    # ----------- Efstathiou -----------
     #  error bar magnitude is always positive.
    ("CMB + DESI DR2 + Des-Dovekie",    -0.870, 0.050, 0.050),  # you can change these values and test with papers
    ("CMB + DESI DR2 + DES-SN5Y",       -0.816, 0.051, 0.051),


]

# ===============================================================
# Compute and print deviations
# ===============================================================
print(f"{'Dataset':45s} {'w0':>8s} {'σ_dev(avg)':>14s}")    # This is header for the table, :45s these number means spacing 
print("-" * 70)                                             # Line to separate header from data (---- line )
for name, w0, em, ep in datasets:
    res = sigma_deviation_from_ref(w0, em, ep)
    print(f"{name:45s} {res['average_error']:14.2f}")

# ===============================================================
# Interpretation table
   # | σ value  | Interpretation                      |
   # | ( < 1σ ) | Fully consistent with ΛCDM          |
   # | ( 1–2σ ) | Very weak preference                |
   # | ( 2–3σ ) | Mild–moderate tension               |
   # | ( 3–4σ ) | Strong indication                   |
   # | ( > 5σ ) | Discovery-level (rare in cosmology) |
# Out:
# Dataset                                             w0     σ_dev(avg)
# ----------------------------------------------------------------------
# CMB + DESI DR2 + Des-Dovekie                            1.44
# CMB + DESI DR2 + DES-SN5Y                               2.29
# CMB + DESI DR2 + Des-Dovekie                            2.60
# CMB + DESI DR2 + DES-SN5Y                               3.88
# CMB + DESI DR2 + Des-Dovekie                            2.30
# CMB + DESI DR2 + DES-SN5Y                               3.42
# CMB + DESI DR2 + Des-Dovekie                            2.53
# CMB + DESI DR2 + DES-SN5Y                               3.32
# CMB + DESI DR2 + Des-Dovekie                            2.60
# CMB + DESI DR2 + DES-SN5Y                               3.61

# %%
# ===============================================================
# Function for computing deviation from reference (fix formula)
# ===============================================================
def sigma_deviation_from_ref(value, err_minus, err_plus, ref=0.0):
    delta = abs(value - ref)
    sigma_avg = (err_minus + err_plus) / 2.0
    n_sigma_avg = delta / sigma_avg
    n_sigma_minus = delta / err_minus
    n_sigma_plus = delta / err_plus
    return {
        "average_error": n_sigma_avg,
        "minus_error": n_sigma_minus,
        "plus_error": n_sigma_plus
    }

# ==============================================================================
# w0 values ± errors extracted from your table , PLUS MINUS error put positive
# ==============================================================================
datasets = [
    # ----------- wCDm -----------
     #  error bar magnitude is always positive.
    ("CMB + DESI DR2 + Des-Dovekie",    -0.34, 0.15, 0.18),  # you can change these values and test with papers
    ("CMB + DESI DR2 + DES-SN5Y",       -0.46, 0.17, 0.17),

]

# ===============================================================
# Compute and print deviations
# ===============================================================
print(f"{'Dataset':45s} {'w0':>8s} {'σ_dev(avg)':>14s}")    # This is header for the table, :45s these number means spacing 
print("-" * 70)                                             # Line to separate header from data (---- line )
for name, w0, em, ep in datasets:
    res = sigma_deviation_from_ref(w0, em, ep)
    print(f"{name:45s} {res['average_error']:14.2f}")

# ===============================================================
# Interpretation table
   # | σ value  | Interpretation                      |
   # | ( < 1σ ) | Fully consistent with ΛCDM          |
   # | ( 1–2σ ) | Very weak preference                |
   # | ( 2–3σ ) | Mild–moderate tension               |
   # | ( 3–4σ ) | Strong indication                   |
   # | ( > 5σ ) | Discovery-level (rare in cosmology) |
# Out:
# Dataset                                             w0     σ_dev(avg)
# ----------------------------------------------------------------------
# CMB + DESI DR2 + Des-Dovekie                            2.06
# CMB + DESI DR2 + DES-SN5Y                               2.71
